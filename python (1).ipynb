# %% [markdown]
# # My Jupyter Notebook on IBM watson Studio

# %% [markdown]
# ## Safeer Ahmad Zaid

# %% [markdown]
# ### 100% Human

# %% [markdown]
# ## I am interested in data science because I love to work with data and get useful insights.

# %% [markdown]
# ### The following code tests the gauss fromula

# %%
def gauss(n):
    return (n*(n+1))/2

gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# * one
# * two
# * three
# * one
# * two
# * three
